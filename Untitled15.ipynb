# %% [markdown]
# <a href="https://colab.research.google.com/github/AnuragPandey19/AI_Matchmaking_VentureLauncher/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3aa78b7d-64ae-4106-ad9b-54a44fad14bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3aa78b7d-64ae-4106-ad9b-54a44fad14bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("synthetic_startup_dataset.csv")

# %%
parquet_file = 'synthetic_startup_dataset.parquet'
df.to_parquet(parquet_file, index=False)

# %%
feather_file = 'synthetic_startup_dataset.feather'
df.to_feather(feather_file)

# %%
csv_size = os.path.getsize("synthetic_startup_dataset.csv") / 1024
parquet_size = os.path.getsize(parquet_file) / 1024
feather_size = os.path.getsize(feather_file) / 1024

# %%
print(f"CSV File Size:     {csv_size:.2f} KB")
print(f"Parquet File Size: {parquet_size:.2f} KB")
print(f"Feather File Size: {feather_size:.2f} KB")
# Out:
# CSV File Size:     28320.29 KB
# Parquet File Size: 11946.44 KB
# Feather File Size: 18223.11 KB

# %%
files.download(parquet_file)
files.download(feather_file)

# %%
import pandas as pd
# Load Feather file
df = pd.read_feather("synthetic_startup_dataset.feather")
df.head()  # to preview the data
# Out:
#                       Startup Name Industry/Sector     Stage  Location/Region  \
# 0  Rodriguez, Figueroa and Sanchez      E-commerce      Idea      Lake Curtis
# 1                   Herrera-Dudley         FinTech      Idea       Millerport
# 2           Nguyen, Tate and Brown      HealthTech  Series B  Port Leslieview
# 3                 Carlson-Mcdonald        AgriTech      Idea        Tashatown
# 4                  Burns-Rodriguez           AI/ML      Seed      Natashaport
#
#    Funding Needs (₹)      Funding Type Business Model  \
# 0            4356886              SAFE            B2C
# 1           30345092  Convertible Note            B2B
# 2            1872248  Convertible Note   Subscription
# 3           49181396              SAFE           SaaS
# 4           85374605              SAFE            B2C
#
#                                     Traction Summary  \
# 0  Beautiful instead ahead despite measure ago cu...
# 1  Peace technology officer relate animal directi...
# ...

# %%
import pandas as pd

# Load Parquet file
df = pd.read_parquet("synthetic_startup_dataset.parquet")
df.head()  # to preview the data
# Out:
#                       Startup Name Industry/Sector     Stage  Location/Region  \
# 0  Rodriguez, Figueroa and Sanchez      E-commerce      Idea      Lake Curtis
# 1                   Herrera-Dudley         FinTech      Idea       Millerport
# 2           Nguyen, Tate and Brown      HealthTech  Series B  Port Leslieview
# 3                 Carlson-Mcdonald        AgriTech      Idea        Tashatown
# 4                  Burns-Rodriguez           AI/ML      Seed      Natashaport
#
#    Funding Needs (₹)      Funding Type Business Model  \
# 0            4356886              SAFE            B2C
# 1           30345092  Convertible Note            B2B
# 2            1872248  Convertible Note   Subscription
# 3           49181396              SAFE           SaaS
# 4           85374605              SAFE            B2C
#
#                                     Traction Summary  \
# 0  Beautiful instead ahead despite measure ago cu...
# 1  Peace technology officer relate animal directi...
# ...
