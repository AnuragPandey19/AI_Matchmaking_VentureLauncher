# %% [markdown]
# <a href="https://colab.research.google.com/github/AnuragPandey19/AI_Matchmaking_VentureLauncher/blob/main/INVESTOR_DATA_OPTIMIZER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2fcdbc08-c7b3-491f-89e3-40c246c4b5ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2fcdbc08-c7b3-491f-89e3-40c246c4b5ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("synthetic_investor_dataset.csv")

# %%
parquet_file = 'synthetic_investor_dataset.parquet'
df.to_parquet(parquet_file, index=False)

# %%
feather_file = 'synthetic_investor_dataset.feather'
df.to_feather(feather_file)

# %%
csv_size = os.path.getsize("synthetic_investor_dataset.csv") / 1024
parquet_size = os.path.getsize(parquet_file) / 1024
feather_size = os.path.getsize(feather_file) / 1024

# %%
print(f"CSV File Size:     {csv_size:.2f} KB")
print(f"Parquet File Size: {parquet_size:.2f} KB")
print(f"Feather File Size: {feather_size:.2f} KB")
# Out:
# CSV File Size:     10037.10 KB
# Parquet File Size: 1760.08 KB
# Feather File Size: 6497.62 KB

# %%
files.download(parquet_file)
files.download(feather_file)

# %%
df = pd.read_feather("synthetic_investor_dataset.feather")
df.head(100002)
# Out:
#                       Name Investor Type            Preferred Startup Stages  \
# 0             Allison Hill         Angel                            Series A
# 1         Stephanie Miller         Angel                                Idea
# 2         Jonathan Johnson            VC                        Growth, Seed
# 3          Connie Lawrence       PE Firm                            Pre-Seed
# 4      Christopher Bernard       PE Firm                            Series A
# ...                    ...           ...                                 ...
# 99995        Bethany Lewis         Angel      Seed, Early Traction, Pre-Seed
# 99996           Cole Burns            VC  Early Traction, Pre-Seed, Series B
# 99997      Ashley Espinoza         Angel        Pre-Seed, Series A, Series B
# 99998     Jennifer Johnson            VC                            Series A
# 99999    Jacqueline Chavez     Corporate                            Series B
#
# ...

# %%
df = pd.read_parquet("synthetic_investor_dataset.parquet")
df.head(100002)
# Out:
#                       Name Investor Type            Preferred Startup Stages  \
# 0             Allison Hill         Angel                            Series A
# 1         Stephanie Miller         Angel                                Idea
# 2         Jonathan Johnson            VC                        Growth, Seed
# 3          Connie Lawrence       PE Firm                            Pre-Seed
# 4      Christopher Bernard       PE Firm                            Series A
# ...                    ...           ...                                 ...
# 99995        Bethany Lewis         Angel      Seed, Early Traction, Pre-Seed
# 99996           Cole Burns            VC  Early Traction, Pre-Seed, Series B
# 99997      Ashley Espinoza         Angel        Pre-Seed, Series A, Series B
# 99998     Jennifer Johnson            VC                            Series A
# 99999    Jacqueline Chavez     Corporate                            Series B
#
# ...
